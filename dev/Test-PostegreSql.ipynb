# %%
import psycopg2
from psycopg2.extras import RealDictCursor

conn = psycopg2.connect(
    host="localhost",  # nom du container
    port=5433,
    dbname="retail_analytics",
    user="retail_user",
    password="retail_pwd"
)

print("Connexion OK")

# Toujours utiliser un curseur explicite
cursor = conn.cursor(cursor_factory=RealDictCursor)
# Out:
# Connexion OK
